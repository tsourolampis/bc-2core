# %%
from bc_alg import *
from bc_util import *

# %% [markdown]
# # Synthetic network with a ranging number of degree-1 nodes

# %%
avg_times, std_times, avg_l1_results, std_l1_results = run_mem_efficient_synthetic(10, core_size=50, central_node=0, filename='synthetic dataset')
# Out:
# Groundtruth BC scores
# Groundtruth BC scores required: 0.0187 seconds
# Memory efficient version with peeling
# Fraction of degree-1 nodes 0.4845360824742268
# Memory efficient version with peeling required: 0.0089 seconds
# Brandes-Pich BC scores
# Groundtruth BC scores required: 0.0018 seconds
# Memory efficient version with peeling and sampling
# Fraction of degree-1 nodes 0.4845360824742268
# Memory efficient version with peeling required: 0.0034 seconds
# Groundtruth BC scores
# Groundtruth BC scores required: 0.0163 seconds
# Memory efficient version with peeling
# Fraction of degree-1 nodes 0.4845360824742268
# Memory efficient version with peeling required: 0.0084 seconds
# Brandes-Pich BC scores
# Groundtruth BC scores required: 0.0017 seconds
# Memory efficient version with peeling and sampling
# Fraction of degree-1 nodes 0.4845360824742268
# Memory efficient version with peeling required: 0.0030 seconds
# Groundtruth BC scores
# ...

# %% [markdown]
# # Karate

# %%
G_karate = nx.karate_club_graph()
times_karate, l1_results_karate = run_mem_efficient_range_k(G_karate,   filename='karate')
# Out:
# Dataset	karate
# Groundtruth BC scores
# Groundtruth BC scores required: 0.0024 seconds
# Memory efficient version with peeling
# Fraction of degree-1 nodes 0.029411764705882353
# Memory efficient version with peeling required: 0.0029 seconds
# Brandes-Pich BC scores
# Groundtruth BC scores required: 0.0003 seconds
# Memory efficient version with peeling and sampling
# Fraction of degree-1 nodes 0.029411764705882353
# Memory efficient version with peeling required: 0.0007 seconds
# Brandes-Pich BC scores
# Groundtruth BC scores required: 0.0006 seconds
# Memory efficient version with peeling and sampling
# Fraction of degree-1 nodes 0.029411764705882353
# Memory efficient version with peeling required: 0.0011 seconds
# Brandes-Pich BC scores
# Groundtruth BC scores required: 0.0012 seconds
# Memory efficient version with peeling and sampling
# Fraction of degree-1 nodes 0.029411764705882353
# Memory efficient version with peeling required: 0.0019 seconds
# Brandes-Pich BC scores
# ...
